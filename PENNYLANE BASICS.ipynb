# %%
import pennylane as qml
import numpy as np

def quantum_function(x, y):
    qml.RZ(x, wires=0)
    qml.CNOT(wires=[0,1])
    qml.RY(y, wires=1)
    return qml.expval(qml.PauliZ(1))

# %%
dev = qml.device('default.qubit', wires=2, shots=1000)

# %%
circuit = qml.QNode(quantum_function, dev)

# %%
import numpy as np
qml.draw_mpl(circuit)(4/3, 0.5)
# Out:
# (<Figure size 600x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np
def quantum(x,y,z):
 qml.RZ(x,wires=0)
 qml.CNOT(wires=[0,1])
 qml.RY(y,wires=1)
 return qml.expval(qml.PauliZ(1))

dev = qml.device('default.qubit',wires=2,shots=1000)
circuit=qml.QNode(quantum,dev)

qml.draw_mpl(circuit)(5,4,3)
# Out:
# (<Figure size 600x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np

def quantum2():
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 qml.CNOT(wires=[0,1])
 qml.Hadamard(wires=0)
 return qml.expval(qml.PauliZ(0)),qml.var(qml.PauliZ(1))

 
dev = qml.device('default.qubit',wires=2,shots=1000)

circuit = qml.QNode(quantum2,dev)

qml.draw_mpl(circuit)()
# Out:
# (<Figure size 600x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np

def quantumfunction():
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1))
shotslist=[1,2,3,4,5]
dev = qml.device('default.qubit',wires=2,shots=shotslist)
circ=qml.QNode(quantumfunction,dev)

result=circ()
print(result[1])
# Out:
# [0. 0.]

# %%
import pennylane as qml
import numpy as np

def quanta():
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1))
dev3=qml.device('default.qubit',wires=2,shots=1000)

circuit2=qml.QNode(quanta,dev3)



print(circuit2())
# Out:
# [-0.002 -0.008]

# %%
import pennylane as qml
import numpy as np
import math as m
alpha=int(input("Enter alpha"))
beta=int(input("Enter beta"))
a=m.sqrt(((alpha)^2+(beta)^2))

print(a)
# Out:
# Enter alpha 1
# Enter beta 1
# 0.0

# %%
import pennylane as qml
import numpy as np

def quanta():
 
 return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1))
dev3=qml.device('default.qubit',wires=2,shots=1000)

circuit2=qml.QNode(quanta,dev3)

qml.draw_mpl(circuit2)()
print(circuit2())
# Out:
# [1. 1.]

# %%
import pennylane as qml
import numpy as np

def deutsch1():
 qml.PauliX(wires=0)
 qml.PauliX(wires=1)
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 qml.PauliX(wires=1)
 qml.Hadamard(wires=0)
 return qml.expval(qml.PauliZ(0))
dev1=qml.device('default.qubit',wires=2,shots=1000)
circuit1=qml.QNode(deutsch1,dev1)

result=circuit1()
print (result)
if result==-1:
 print("The function is constant")
qml.draw_mpl(circuit1)()
# Out:
# -1.0
# The function is constant
# (<Figure size 600x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np

def deutsch2():
 qml.PauliX(wires=0)
 qml.PauliX(wires=1)
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 qml.Identity(wires=1)
 qml.Hadamard(wires=0)
 return qml.expval(qml.PauliZ(0))
dev2=qml.device('default.qubit',wires=2,shots=1000)

circuit2=qml.QNode(deutsch2,dev2)
result = circuit2()
print(result)
if result==-1:
 print("The function is constant")
qml.draw_mpl(circuit2)()
# Out:
# -1.0
# The function is constant
# (<Figure size 600x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np

def deutsch3():
 qml.PauliX(wires=0)
 qml.PauliX(wires=1)
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 qml.PauliX(wires=1)
 qml.CNOT(wires=[0,1])
 qml.Hadamard(wires=0)
 return qml.expval(qml.PauliZ(0))

dev3 = qml.device('default.qubit',wires=2,shots=1000)
circuit3=qml.QNode(deutsch3,dev3)

result=circuit3()
print(result)
if result==1:
 print("The function is balanced")
qml.draw_mpl(circuit3)()
# Out:
# 1.0
# The function is balanced
# (<Figure size 800x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np

def deutsch4():
 qml.PauliX(wires=0)
 qml.PauliX(wires=1)
 qml.Hadamard(wires=0)
 qml.Hadamard(wires=1)
 qml.CNOT(wires=[0,1])
 qml.Hadamard(wires=0)
 return qml.expval(qml.PauliZ(0))

dev4 = qml.device('default.qubit',wires=2,shots=1000)
circuit4=qml.QNode(deutsch4,dev4)

result=circuit4()
print(result)
if result==1:
 print("The function is balanced")
qml.draw_mpl(circuit4)()
# Out:
# 1.0
# The function is balanced
# (<Figure size 700x300 with 1 Axes>, <Axes: >)

# %%
import pennylane as qml
import numpy as np
